# %%
import pandas as pd
import os 
import matplotlib.pyplot as plt

path = "C:/Users/Admin/Desktop/NCKH 2022/"
file_name = "vatlieu1421_new.xlsx"

# %%
for i in range(2014,2022):
    df["1. Phải thu dài hạn Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"] = pd.to_numeric(df["1. Phải thu dài hạn Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"], downcast="integer" )
    df["3. Các khoản phải thu ngắn hạn Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"] = pd.to_numeric(df["3. Các khoản phải thu ngắn hạn Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"], downcast="integer" )

# %%
df = pd.read_excel(path + file_name)
df.head()
# Out:
#    STT Mã CK                          Tên   Sàn  Phân ngành - ICB Cấp: 3  \
# 0    8   ACC  Đầu tư và XD Bình Dương ACC  HOSE  Xây dựng và Vật liệu L3
# 1  440   BCC              Xi măng Bỉm Sơn   HNX  Xây dựng và Vật liệu L3
# 2  451   BTS              Xi măng Bút Sơn   HNX  Xây dựng và Vật liệu L3
# 3  498   DTC         Viglacera Đông Triều   HNX  Xây dựng và Vật liệu L3
# 4  103   DTL                Đại Thiên Lộc  HOSE              Kim loại L3
#
#    Giá đóng cửa (D) Ngày GD: 2014-12-31 Đơn vị: VND  \
# 0                                             31900
# 1                                             14900
# 2                                              7600
# 3                                              5900
# 4                                              9300
#
#    Giá đóng cửa (D) Ngày GD: 2015-12-31 Đơn vị: VND  \
# 0                                             24300
# 1                                             13400
# ...

# %%
for i in range(2014,2022):
    df["Tổng các khoản phải thu " + str(i)] = df["1. Phải thu dài hạn Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"] + df["3. Các khoản phải thu ngắn hạn Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"]
df.head()
# Out:
#    STT Mã CK                          Tên   Sàn  Phân ngành - ICB Cấp: 3  \
# 0    8   ACC  Đầu tư và XD Bình Dương ACC  HOSE  Xây dựng và Vật liệu L3
# 1  440   BCC              Xi măng Bỉm Sơn   HNX  Xây dựng và Vật liệu L3
# 2  451   BTS              Xi măng Bút Sơn   HNX  Xây dựng và Vật liệu L3
# 3  498   DTC         Viglacera Đông Triều   HNX  Xây dựng và Vật liệu L3
# 4  103   DTL                Đại Thiên Lộc  HOSE              Kim loại L3
#
#    Giá đóng cửa (D) Ngày GD: 2014-12-31 Đơn vị: VND  \
# 0                                             31900
# 1                                             14900
# 2                                              7600
# 3                                              5900
# 4                                              9300
#
#    Giá đóng cửa (D) Ngày GD: 2015-12-31 Đơn vị: VND  \
# 0                                             24300
# 1                                             13400
# ...

# %%
for i in range(2014,2022):
    df["I. TÀI SẢN NGẮN HẠN Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"] = pd.to_numeric(df["I. TÀI SẢN NGẮN HẠN Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"], downcast="float" )
    df["1. Nợ ngắn hạn Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"]= pd.to_numeric(df["1. Nợ ngắn hạn Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"], downcast="float")
    df["2. Khấu hao TSCĐ (GT) Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"] = pd.to_numeric(df["2. Khấu hao TSCĐ (GT) Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"], downcast="float" )

# %%
for i in range(2014,2022):
    df["Tổng dồn tích " + str(i)] = (df["I. TÀI SẢN NGẮN HẠN Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"] - df["I. TÀI SẢN NGẮN HẠN Hợp nhất Năm: " + str(i-1) + " Quý: Hàng năm Đơn vị: VND"]) - (df["1. Nợ ngắn hạn Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"] - df["1. Nợ ngắn hạn Hợp nhất Năm: " + str(i-1) + " Quý: Hàng năm Đơn vị: VND"]) - df["2. Khấu hao TSCĐ (GT) Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"]
df.head()
# Out:
#    STT Mã CK                          Tên   Sàn  Phân ngành - ICB Cấp: 3  \
# 0    8   ACC  Đầu tư và XD Bình Dương ACC  HOSE  Xây dựng và Vật liệu L3
# 1  440   BCC              Xi măng Bỉm Sơn   HNX  Xây dựng và Vật liệu L3
# 2  451   BTS              Xi măng Bút Sơn   HNX  Xây dựng và Vật liệu L3
# 3  498   DTC         Viglacera Đông Triều   HNX  Xây dựng và Vật liệu L3
# 4  103   DTL                Đại Thiên Lộc  HOSE              Kim loại L3
#
#    Giá đóng cửa (D) Ngày GD: 2014-12-31 Đơn vị: VND  \
# 0                                             31900
# 1                                             14900
# 2                                              7600
# 3                                              5900
# 4                                              9300
#
#    Giá đóng cửa (D) Ngày GD: 2015-12-31 Đơn vị: VND  \
# 0                                             24300
# 1                                             13400
# ...

# %%
for i in range(2014,2022):
    df["EPS cơ bản Chỉ số hàng năm Năm: " + str(i) + " Đơn vị: VND"] = pd.to_numeric(df["EPS cơ bản Chỉ số hàng năm Năm: " + str(i) + " Đơn vị: VND"], downcast="float" )
    df["4.1. Hàng tồn kho Hợp nhất Năm: "+ str(i) +" Quý: Hàng năm Đơn vị: VND"]= pd.to_numeric(df["4.1. Hàng tồn kho Hợp nhất Năm: "+ str(i) +" Quý: Hàng năm Đơn vị: VND"], downcast="float")
    df["1. Doanh thu bán hàng và cung cấp dịch vụ Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"] = pd.to_numeric(df["1. Doanh thu bán hàng và cung cấp dịch vụ Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"], downcast="float" )

# %%
for i in range(2014,2022):
    df["EPS*INV/SALES " + str(i)] = df["EPS cơ bản Chỉ số hàng năm Năm: " + str(i) + " Đơn vị: VND"] *  df["4.1. Hàng tồn kho Hợp nhất Năm: "+ str(i) +" Quý: Hàng năm Đơn vị: VND"] / df["1. Doanh thu bán hàng và cung cấp dịch vụ Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"]
df.head()
# Out:
#    STT Mã CK                          Tên   Sàn  Phân ngành - ICB Cấp: 3  \
# 0    8   ACC  Đầu tư và XD Bình Dương ACC  HOSE  Xây dựng và Vật liệu L3
# 1  440   BCC              Xi măng Bỉm Sơn   HNX  Xây dựng và Vật liệu L3
# 2  451   BTS              Xi măng Bút Sơn   HNX  Xây dựng và Vật liệu L3
# 3  498   DTC         Viglacera Đông Triều   HNX  Xây dựng và Vật liệu L3
# 4  103   DTL                Đại Thiên Lộc  HOSE              Kim loại L3
#
#    Giá đóng cửa (D) Ngày GD: 2014-12-31 Đơn vị: VND  \
# 0                                             31900
# 1                                             14900
# 2                                              7600
# 3                                              5900
# 4                                              9300
#
#    Giá đóng cửa (D) Ngày GD: 2015-12-31 Đơn vị: VND  \
# 0                                             24300
# 1                                             13400
# ...

# %%
for i in range(2014,2022):
    df["I. NỢ PHẢI TRẢ Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"]= pd.to_numeric(df["I. NỢ PHẢI TRẢ Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"], downcast="float")
    df["A. TỔNG CỘNG TÀI SẢN Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"] = pd.to_numeric(df["A. TỔNG CỘNG TÀI SẢN Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"], downcast="float" )

# %%
for i in range(2014,2022):
    df["EPS*TD/TA " + str(i)] = df["EPS cơ bản Chỉ số hàng năm Năm: " + str(i) + " Đơn vị: VND"] * df["I. NỢ PHẢI TRẢ Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"] / df["A. TỔNG CỘNG TÀI SẢN Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"]
df.head()
# Out:
#    STT Mã CK                          Tên   Sàn  Phân ngành - ICB Cấp: 3  \
# 0    8   ACC  Đầu tư và XD Bình Dương ACC  HOSE  Xây dựng và Vật liệu L3
# 1  440   BCC              Xi măng Bỉm Sơn   HNX  Xây dựng và Vật liệu L3
# 2  451   BTS              Xi măng Bút Sơn   HNX  Xây dựng và Vật liệu L3
# 3  498   DTC         Viglacera Đông Triều   HNX  Xây dựng và Vật liệu L3
# 4  103   DTL                Đại Thiên Lộc  HOSE              Kim loại L3
#
#    Giá đóng cửa (D) Ngày GD: 2014-12-31 Đơn vị: VND  \
# 0                                             31900
# 1                                             14900
# 2                                              7600
# 3                                              5900
# 4                                              9300
#
#    Giá đóng cửa (D) Ngày GD: 2015-12-31 Đơn vị: VND  \
# 0                                             24300
# 1                                             13400
# ...

# %%
for i in range(2014,2022):
     df["Vốn lưu động " + str(i)]= pd.to_numeric(df["Vốn lưu động " + str(i)], downcast="float")

# %%
for i in range(2014,2022):
    df["EPS*WC/TA " + str(i)] = df["EPS cơ bản Chỉ số hàng năm Năm: " + str(i) + " Đơn vị: VND"] * df["Vốn lưu động " + str(i)] / df["A. TỔNG CỘNG TÀI SẢN Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"]
df.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_25304/118926011.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["EPS*WC/TA " + str(i)] = df["EPS cơ bản Chỉ số hàng năm Năm: " + str(i) + " Đơn vị: VND"] * df["Vốn lưu động " + str(i)] / df["A. TỔNG CỘNG TÀI SẢN Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"]
#    STT Mã CK                          Tên   Sàn  Phân ngành - ICB Cấp: 3  \
# 0    8   ACC  Đầu tư và XD Bình Dương ACC  HOSE  Xây dựng và Vật liệu L3
# 1  440   BCC              Xi măng Bỉm Sơn   HNX  Xây dựng và Vật liệu L3
# 2  451   BTS              Xi măng Bút Sơn   HNX  Xây dựng và Vật liệu L3
# 3  498   DTC         Viglacera Đông Triều   HNX  Xây dựng và Vật liệu L3
# ...

# %%
for i in range(2014,2022):
     df["16. Tổng lợi nhuận kế toán trước thuế Hợp nhất Năm: "+ str(i) + " Quý: Hàng năm Đơn vị: VND"]= pd.to_numeric(df["16. Tổng lợi nhuận kế toán trước thuế Hợp nhất Năm: "+ str(i) + " Quý: Hàng năm Đơn vị: VND"], downcast="float")

# %%
for i in range(2014,2022):
    df["EPS*NP/TA " + str(i)] = df["EPS cơ bản Chỉ số hàng năm Năm: " + str(i) + " Đơn vị: VND"] * df["16. Tổng lợi nhuận kế toán trước thuế Hợp nhất Năm: "+ str(i) + " Quý: Hàng năm Đơn vị: VND"] / df["A. TỔNG CỘNG TÀI SẢN Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"]
df.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_25304/63452706.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["EPS*NP/TA " + str(i)] = df["EPS cơ bản Chỉ số hàng năm Năm: " + str(i) + " Đơn vị: VND"] * df["16. Tổng lợi nhuận kế toán trước thuế Hợp nhất Năm: "+ str(i) + " Quý: Hàng năm Đơn vị: VND"] / df["A. TỔNG CỘNG TÀI SẢN Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"]
#    STT Mã CK                          Tên   Sàn  Phân ngành - ICB Cấp: 3  \
# 0    8   ACC  Đầu tư và XD Bình Dương ACC  HOSE  Xây dựng và Vật liệu L3
# 1  440   BCC              Xi măng Bỉm Sơn   HNX  Xây dựng và Vật liệu L3
# 2  451   BTS              Xi măng Bút Sơn   HNX  Xây dựng và Vật liệu L3
# ...

# %%
for i in range(2014,2022):
    df["EPS*NP/SALES " + str(i)] = df["EPS cơ bản Chỉ số hàng năm Năm: " + str(i) + " Đơn vị: VND"] * df["16. Tổng lợi nhuận kế toán trước thuế Hợp nhất Năm: "+ str(i) + " Quý: Hàng năm Đơn vị: VND"] / df["1. Doanh thu bán hàng và cung cấp dịch vụ Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"]
df.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_25304/3596364531.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["EPS*NP/SALES " + str(i)] = df["EPS cơ bản Chỉ số hàng năm Năm: " + str(i) + " Đơn vị: VND"] * df["16. Tổng lợi nhuận kế toán trước thuế Hợp nhất Năm: "+ str(i) + " Quý: Hàng năm Đơn vị: VND"] / df["1. Doanh thu bán hàng và cung cấp dịch vụ Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"]
#    STT Mã CK                          Tên   Sàn  Phân ngành - ICB Cấp: 3  \
# 0    8   ACC  Đầu tư và XD Bình Dương ACC  HOSE  Xây dựng và Vật liệu L3
# 1  440   BCC              Xi măng Bỉm Sơn   HNX  Xây dựng và Vật liệu L3
# 2  451   BTS              Xi măng Bút Sơn   HNX  Xây dựng và Vật liệu L3
# ...

# %%
for i in range(2014,2022):
    df["EPS*SALES/TA " + str(i)] = df["EPS cơ bản Chỉ số hàng năm Năm: " + str(i) + " Đơn vị: VND"] * df["1. Doanh thu bán hàng và cung cấp dịch vụ Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"] / df["A. TỔNG CỘNG TÀI SẢN Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"]
df.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_25304/3211795242.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["EPS*SALES/TA " + str(i)] = df["EPS cơ bản Chỉ số hàng năm Năm: " + str(i) + " Đơn vị: VND"] * df["1. Doanh thu bán hàng và cung cấp dịch vụ Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"] / df["A. TỔNG CỘNG TÀI SẢN Hợp nhất Năm: " + str(i) + " Quý: Hàng năm Đơn vị: VND"]
#    STT Mã CK                          Tên   Sàn  Phân ngành - ICB Cấp: 3  \
# 0    8   ACC  Đầu tư và XD Bình Dương ACC  HOSE  Xây dựng và Vật liệu L3
# 1  440   BCC              Xi măng Bỉm Sơn   HNX  Xây dựng và Vật liệu L3
# 2  451   BTS              Xi măng Bút Sơn   HNX  Xây dựng và Vật liệu L3
# ...

# %%
df.to_excel("vatlieu1421_NEW_clean.xlsx", index=False)
